# %% [markdown]
# ##  0. imports and parameters setup¶

# %%
# imports

from keras.applications import vgg16

from keras.preprocessing.image import load_img,img_to_array
from keras.models import Model
from keras.applications.imagenet_utils import preprocess_input

from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
# Out:
# Using TensorFlow backend.
# /Users/victorgalan/miniconda3/envs/keras_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/victorgalan/miniconda3/envs/keras_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/victorgalan/miniconda3/envs/keras_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/victorgalan/miniconda3/envs/keras_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/victorgalan/miniconda3/envs/keras_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/victorgalan/miniconda3/envs/keras_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Parameters setup

# %%
imgs_path = "../ikea_scraper/img_ikea_Sillas/"

# %%
# parameters setup

imgs_model_width, imgs_model_height = 224, 224

nb_closest_images = 5 # number of most similar images to retrieve

# %%
##  1. load the VGG pre-trained model from Keras¶

# %%
# load the model
vgg_model = vgg16.VGG16(weights='imagenet')

# remove the last layers in order to get features instead of predictions
feat_extractor = Model(inputs=vgg_model.input, outputs=vgg_model.get_layer("fc2").output)

# print the layers of the CNN
feat_extractor.summary()
# Out:
# WARNING:tensorflow:From /Users/victorgalan/miniconda3/envs/keras_env/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##  2. get the images paths

# %%
files = [imgs_path + x for x in os.listdir(imgs_path) if "jpg" in x]

print("number of images:",len(files))
# Out:
# number of images: 945

# %% [markdown]
# ##  3. feed one image into the CNN

# %%
files[3]
# Out:
# '../ikea_scraper/img_ikea_Sillas/0065.jpg'

# %%
imgs_real_path = "./test_images/"

# %%
files_real = [imgs_real_path + x for x in os.listdir(imgs_real_path) if "jpeg" in x]

print("number of images:",len(files_real))
# Out:
# number of images: 1

# %%
# load an image in PIL format
original = load_img(files_real[0], target_size=(imgs_model_width, imgs_model_height))
plt.imshow(original)
plt.show()
print("image loaded successfully!")
# Out:
# image loaded successfully!

# %%
# convert the PIL image to a numpy array
# in PIL - image is in (width, height, channel)
# in Numpy - image is in (height, width, channel)
numpy_image = img_to_array(original)

# convert the image / images into batch format
# expand_dims will add an extra dimension to the data at a particular axis
# we want the input matrix to the network to be of the form (batchsize, height, width, channels)
# thus we add the extra dimension to the axis 0.
image_batch = np.expand_dims(numpy_image, axis=0)
print('image batch size', image_batch.shape)

# prepare the image for the VGG model
processed_image = preprocess_input(image_batch.copy())
# Out:
# image batch size (1, 224, 224, 3)

# %%
# get the extracted features
img_features = feat_extractor.predict(processed_image)

print("features successfully extracted!")
print("number of image features:",img_features.size)
img_features
# Out:
# features successfully extracted!
# number of image features: 4096
# array([[0.       , 1.8393655, 0.       , ..., 0.       , 0.       ,
#         0.       ]], dtype=float32)

# %% [markdown]
# ## 4. feed all the images into the CNN

# %%
# load all the images and prepare them for feeding into the CNN

importedImages = []

for f in files:
    filename = f
    original = load_img(filename, target_size=(224, 224))
    numpy_image = img_to_array(original)
    image_batch = np.expand_dims(numpy_image, axis=0)
    
    importedImages.append(image_batch)
    
images = np.vstack(importedImages)

processed_imgs = preprocess_input(images.copy())

# %%
# extract the images features

imgs_features = feat_extractor.predict(processed_imgs)

print("features successfully extracted!")
imgs_features.shape
# Out:
# features successfully extracted!
# (945, 4096)

# %% [markdown]
# ## 5. compute cosine similarities

# %%
# compute cosine similarities between images

cosSimilarities = cosine_similarity(imgs_features)

# store the results into a pandas dataframe

cos_similarities_df = pd.DataFrame(cosSimilarities, columns=files, index=files)
cos_similarities_df.head()
# Out:
#                                           ../ikea_scraper/img_ikea_Sillas/0071.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  1.000000
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.462300
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.507542
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.490823
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.529097
#
#                                           ../ikea_scraper/img_ikea_Sillas/0717.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.462300
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  1.000000
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.772980
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.405021
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.374840
#
#                                           ../ikea_scraper/img_ikea_Sillas/0703.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.507542
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.772980
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  1.000000
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.481558
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.430111
#
#                                           ../ikea_scraper/img_ikea_Sillas/0065.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.490823
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.405021
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.481558
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  1.000000
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.733503
#
#                                           ../ikea_scraper/img_ikea_Sillas/0059.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.529097
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.374840
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.430111
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.733503
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  1.000000
#
#                                           ../ikea_scraper/img_ikea_Sillas/0918.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.493154
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.369218
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.415060
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.688442
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.647456
#
#                                           ../ikea_scraper/img_ikea_Sillas/0930.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.378959
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.407551
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.423809
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.391956
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.462737
#
#                                           ../ikea_scraper/img_ikea_Sillas/0924.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.566073
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.589643
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.593188
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.437419
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.463415
#
#                                           ../ikea_scraper/img_ikea_Sillas/0515.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.212833
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.262714
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.254546
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.323758
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.446543
#
#                                           ../ikea_scraper/img_ikea_Sillas/0273.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.302116
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.291275
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.275574
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.522802
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.589838
#
#                                           ...  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg  ...
# ../ikea_scraper/img_ikea_Sillas/0717.jpg  ...
# ../ikea_scraper/img_ikea_Sillas/0703.jpg  ...
# ../ikea_scraper/img_ikea_Sillas/0065.jpg  ...
# ../ikea_scraper/img_ikea_Sillas/0059.jpg  ...
#
#                                           ../ikea_scraper/img_ikea_Sillas/0083.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.552546
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.636432
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.574108
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.379348
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.452661
#
#                                           ../ikea_scraper/img_ikea_Sillas/0929.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.329638
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.348158
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.371901
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.379477
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.464063
#
#                                           ../ikea_scraper/img_ikea_Sillas/0097.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.516608
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.401838
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.473553
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.606809
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.615206
#
#                                           ../ikea_scraper/img_ikea_Sillas/0901.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.330191
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.386661
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.366189
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.354889
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.441902
#
#                                           ../ikea_scraper/img_ikea_Sillas/0915.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.357130
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.296757
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.270388
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.412501
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.504597
#
#                                           ../ikea_scraper/img_ikea_Sillas/0040.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.557130
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.422810
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.498692
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.519791
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.566177
#
#                                           ../ikea_scraper/img_ikea_Sillas/0726.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.493356
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.357864
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.436819
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.524389
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.610771
#
#                                           ../ikea_scraper/img_ikea_Sillas/0732.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.386224
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.332423
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.324949
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.662814
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.627878
#
#                                           ../ikea_scraper/img_ikea_Sillas/0054.jpg  \
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.516125
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.454549
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.540584
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.840271
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.777495
#
#                                           ../ikea_scraper/img_ikea_Sillas/0068.jpg
# ../ikea_scraper/img_ikea_Sillas/0071.jpg                                  0.508566
# ../ikea_scraper/img_ikea_Sillas/0717.jpg                                  0.352192
# ../ikea_scraper/img_ikea_Sillas/0703.jpg                                  0.380337
# ../ikea_scraper/img_ikea_Sillas/0065.jpg                                  0.482379
# ../ikea_scraper/img_ikea_Sillas/0059.jpg                                  0.507208
#
# [5 rows x 945 columns]

# %% [markdown]
# ## 6. retrieve most similar products

# %%
# function to retrieve the most similar products for a given one

def retrieve_most_similar_products(given_img):

    print("-----------------------------------------------------------------------")
    print("original product:")

    original = load_img(given_img, target_size=(imgs_model_width, imgs_model_height))
    plt.imshow(original)
    plt.show()

    print("-----------------------------------------------------------------------")
    print("most similar products:")

    closest_imgs = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1].index
    closest_imgs_scores = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1]

    for i in range(0,len(closest_imgs)):
        original = load_img(closest_imgs[i], target_size=(imgs_model_width, imgs_model_height))
        plt.imshow(original)
        plt.show()
        print("similarity score : ",closest_imgs_scores[i])

# %%
retrieve_most_similar_products(files[1])
# Out:
# -----------------------------------------------------------------------
# original product:
# -----------------------------------------------------------------------
# most similar products:
# similarity score :  0.88849026
# similarity score :  0.8128507
# similarity score :  0.8049126
# similarity score :  0.7729803
# similarity score :  0.7698926

# %%
retrieve_most_similar_products(files[0])
# Out:
# -----------------------------------------------------------------------
# original product:
# -----------------------------------------------------------------------
# most similar products:
# similarity score :  0.8226048
# similarity score :  0.82046455
# similarity score :  0.77131057
# similarity score :  0.76360416
# similarity score :  0.7454176

# %%
from IPython.display import Image

Image(filename=files[5])

# %%
retrieve_most_similar_products(files[5])
# Out:
# -----------------------------------------------------------------------
# original product:
# -----------------------------------------------------------------------
# most similar products:
# similarity score :  0.9739373
# similarity score :  0.96957636
# similarity score :  0.96061087
# similarity score :  0.9142945
# similarity score :  0.9085758

# %%
Image(filename=files_real[0])

# %%
retrieve_most_similar_products(files_real[0])
# Out:
# -----------------------------------------------------------------------
# original product:
# -----------------------------------------------------------------------
# most similar products:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/keras_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: './test_images/realtest.jpeg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-ef0bfb6be0a3> in <module>
# ----> 1 retrieve_most_similar_products(files_real[0])
#
# <ipython-input-46-bc886a56b404> in retrieve_most_similar_products(given_img)
#      13     print("most similar products:")
#      14
# ---> 15     closest_imgs = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1].index
#      16     closest_imgs_scores = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1]
#      17
#
# ~/miniconda3/envs/keras_env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/miniconda3/envs/keras_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: './test_images/realtest.jpeg'
